# %%
import pandas as pd
fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
data = pd.read_csv(fileURL, names=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Name'], header=None)

# %% [markdown]
# ## Part 1 – Iris Dataset
# #### 1.1 Summary Statistics

# %%
# Print the first 5 elements
data.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Data types
data.dtypes
# Out:
# Sepal Length    float64
# Sepal Width     float64
# Petal Length    float64
# Petal Width     float64
# Name             object
# dtype: object

# %%
# Compute and display summary statistics for each feature
# The results of each features are listed below.
data.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# The variance of each features are listed below
data.var()
# Out:
# Sepal Length    0.685694
# Sepal Width     0.188004
# Petal Length    3.113179
# Petal Width     0.582414
# dtype: float64

# %% [markdown]
# #### 1.2 Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Histogram
data[[0,1]].plot.hist(alpha = 0.5)
data[[2,3]].plot.hist(alpha = 0.5)

# %%
# Box Plots
data.plot.box()

# %% [markdown]
# ## Part 2 – Pen-Based Handwritten Digits Dataset
# #### 2.1 Summary Statistics

# %%
fileURL2 = 'http://archive.ics.uci.edu/ml/datasets/Pen-Based+Recognition+of+Handwritten+Digits'
t_name = ['att1', 'att2', 'att3', 'att4', 'att5', 'att6', 'att7', 'att8', 'att9', 'att10', 'att11', 'att12', 'att13', 'att14', 'att15', 'att16', 'class code']
data2 = pd.read_table('pendigits.tra', sep=',', header=None, names = t_name, engine='python')
data2.head()
# Print the first 5 elements
# Out:
#    att1  att2  att3  att4  att5  att6  att7  att8  att9  att10  att11  att12  \
# 0    47   100    27    81    57    37    26     0     0     23     56     53
# 1     0    89    27   100    42    75    29    45    15     15     37      0
# 2     0    57    31    68    72    90   100   100    76     75     50     51
# 3     0   100     7    92     5    68    19    45    86     34    100     45
# 4     0    67    49    83   100   100    81    80    60     60     40     40
#
#    att13  att14  att15  att16  class code
# 0    100     90     40     98           8
# 1     69      2    100      6           2
# 2     28     25     16      0           1
# 3     74     23     67      0           4
# 4     33     20     47      0           1

# %%
# Data Types
data2.dtypes
# Out:
# att1          int64
# att2          int64
# att3          int64
# att4          int64
# att5          int64
# att6          int64
# att7          int64
# att8          int64
# att9          int64
# att10         int64
# att11         int64
# att12         int64
# att13         int64
# att14         int64
# att15         int64
# att16         int64
# class code    int64
# dtype: object

# %%
# Compute and display summary statistics for each feature
# The results of each features are listed below.
data2.describe()
# Out:
#               att1         att2         att3         att4         att5  \
# count  7494.000000  7494.000000  7494.000000  7494.000000  7494.000000
# mean     37.384307    84.679343    40.005604    82.889512    50.878303
# std      33.322024    16.848420    26.256025    19.638582    34.927201
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000    76.000000    20.000000    70.000000    17.000000
# 50%      31.000000    89.000000    39.000000    89.000000    56.000000
# 75%      61.000000   100.000000    58.000000   100.000000    81.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#               att6         att7         att8         att9        att10  \
# count  7494.000000  7494.000000  7494.000000  7494.000000  7494.000000
# mean     65.044436    51.471844    44.599680    57.129971    34.069122
# std      27.377341    30.680075    30.659478    33.680340    27.459989
# ...

# %%
# The variance of each features are listed below
data2.var()
# Out:
# att1          1110.357293
# att2           283.869273
# att3           689.378856
# att4           385.673898
# att5          1219.909384
# att6           749.518778
# att7           941.266990
# att8           940.003609
# att9          1134.365329
# att10          754.051007
# att11         1378.693497
# att12          756.020974
# att13          510.750095
# att14         1103.808295
# att15         1724.889891
# att16         1282.434467
# class code       8.277018
# dtype: float64

# %% [markdown]
# #### 2.2 Data Visualization

# %%
# Histogram
data2[[0,1]].plot.hist(alpha= 0.6)
data2[[2,3]].plot.hist(alpha= 0.6)
data2[[4,5]].plot.hist(alpha= 0.6)
data2[[6,7]].plot.hist(alpha= 0.6)
data2[[8,9]].plot.hist(alpha= 0.6)
data2[[10,11]].plot.hist(alpha= 0.6)
data2[[12,13]].plot.hist(alpha= 0.6)
data2[[14,15]].plot.hist(alpha= 0.6)
data2[[16]].plot.hist()

# %%
# Box Plots
data2.plot.box()
data2[[0,1,2,3,4,5,6,7]].plot.box()
data2[[8,9,10,11,12,13,14,15]].plot.box()
data2[[16]].plot.box()

# %% [markdown]
# ## Part 3 – Conceptual Questions
# #### 3-1
# 1. The shape of sepal length is more evenly distributed than the shape of petal length. For the shape of sepal width, the data are mainly concentrated in the middle area while the shape of petal width is scattered distributed.
#
# 2. We can see from the plot that there is no value in the range about 2 to 3. I think 2.5 could be a good value to segment it into two parts.
#
# #### 3-2
# 1. Sepal length and petal width have significantly different median since the red line of these two plots have the longest distance.
#
# 2. Petal length appears to explain the greatest amount of the data because it has the greatest range of data.
#
# #### 3-3
# 1. Yes, there are some outliers for the second and fourth features.
#
# 2. The second and fourth features are mainly consentrated in the high value range. But there are a few data appeared at the low value area. These data displayed as a really small rectangle in the plot and seems not closely related to other rectangles.
